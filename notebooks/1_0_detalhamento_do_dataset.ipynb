# %% [markdown]
# Vou utilizar os arquivos que estão descritos na pasta `limited_supervision` para cada idioma.
#
# Vou avaliar o tamanho dos áudios concatenados (total dá 1 hora de áudio?) e proporção de áudios masculinos e femininos.

# %%
import os
import gc
import pandas as pd
import numpy as np
import glob

import librosa
import librosa.display
import IPython.display as ipd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
LANGUAGE_PATH = "../data/mls/mls_{}"
IDS_PATH = os.path.join(LANGUAGE_PATH, "train/limited_supervision/1hr/{}") # language, folder
AUDIO_PATH = os.path.join(LANGUAGE_PATH, "train/audio/{}/{}/{}.flac") # language, speaker, book, id
LANGUAGES = ["italian", "polish", "portuguese", "spanish"]
FOLDERS = list(range(0, 6))

# %%
FOLDERS
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# Vou obter todos os IDs que estão nos arquivos `handles.txt`

# %%
def get_content_from_file(filepath):
    with open(filepath) as f:
        lines = f.readlines()
    lines = [line[:-1] for line in lines]
    return lines

# %%
#get_content_from_file("../data/mls/mls_italian/train/limited_supervision/1hr/0/handles.txt")

# %%
ids_map = pd.DataFrame(columns=["language", "ids"])
for language in LANGUAGES:
    print("Idioma: {}".format(language))
    ids = []
    for folder in FOLDERS:
        print("Folder {}".format(folder))
        data_path = IDS_PATH.format(language, folder)
        content = get_content_from_file(os.path.join(data_path, "handles.txt"))
        ids = ids + content
    ids_map.loc[len(ids_map), :] = [language, ids]
    print()
# Out:
# Idioma: italian
# Folder 0
# Folder 1
# Folder 2
# Folder 3
# Folder 4
# Folder 5
#
# Idioma: polish
# Folder 0
# Folder 1
# Folder 2
# Folder 3
# Folder 4
# Folder 5
#
# Idioma: portuguese
# Folder 0
# Folder 1
# Folder 2
# Folder 3
# Folder 4
# Folder 5
#
# Idioma: spanish
# Folder 0
# Folder 1
# Folder 2
# Folder 3
# Folder 4
# Folder 5
# /Users/marcospaulo/Projects/multilingual_classification/venv/lib/python3.9/site-packages/pandas/core/internals/blocks.py:940: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# /Users/marcospaulo/Projects/multilingual_classification/venv/lib/python3.9/site-packages/pandas/core/internals/blocks.py:940: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# /Users/marcospaulo/Projects/multilingual_classification/venv/lib/python3.9/site-packages/pandas/core/internals/blocks.py:940: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# /Users/marcospaulo/Projects/multilingual_classification/venv/lib/python3.9/site-packages/pandas/core/internals/blocks.py:940: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)

# %%
ids_map
# Out:
#      language                                                ids
# 0     italian  [8828_8610_000510, 659_547_000790, 643_529_000...
# 1      polish  [4228_1447_000021, 7014_6288_000494, 1329_1447...
# 2  portuguese  [10199_6390_000016, 12249_12879_002169, 3718_2...
# 3     spanish  [12332_10604_000010, 11772_11957_000011, 13690...

# %% [markdown]
# Quantos áudios temos para cada idioma?

# %%
ids_map["count"] = ids_map["ids"].apply(len)

# %%
ids_map
# Out:
#      language                                                ids  count
# 0     italian  [8828_8610_000510, 659_547_000790, 643_529_000...    240
# 1      polish  [4228_1447_000021, 7014_6288_000494, 1329_1447...    238
# 2  portuguese  [10199_6390_000016, 12249_12879_002169, 3718_2...    236
# 3     spanish  [12332_10604_000010, 11772_11957_000011, 13690...    233

# %%
ids_map["count"].sum()
# Out:
# 947

# %% [markdown]
# Vamos ler os áudios para entender as características do nosso dataset

# %%
ids_map = ids_map.drop(columns=["count"])

# %%
df_audios = ids_map.explode("ids").reset_index(drop=True)
df_audios = df_audios.rename(columns={"ids":"id"})

# %%
# "id", "language",  "speaker", "book", "segment"
df_audios["id_splitted"] = df_audios["id"].str.split("_")
df_audios["speaker"] = df_audios["id_splitted"].apply(lambda x : x[0])
df_audios["book"] = df_audios["id_splitted"].apply(lambda x : x[1])
df_audios["segment"] = df_audios["id_splitted"].apply(lambda x : x[2])
df_audios = df_audios.drop(columns=["id_splitted"])

# %%
df_audios = df_audios.astype(str)

# %%
df_audios
# Out:
#     language                id speaker  book segment
# 0    italian  8828_8610_000510    8828  8610  000510
# 1    italian    659_547_000790     659   547  000790
# 2    italian    643_529_000116     643   529  000116
# 3    italian  8828_8610_000321    8828  8610  000321
# 4    italian    659_547_000279     659   547  000279
# ..       ...               ...     ...   ...     ...
# 942  spanish  6156_4006_000020    6156  4006  000020
# 943  spanish    101_567_000034     101   567  000034
# 944  spanish  8881_8550_000536    8881  8550  000536
# 945  spanish  6156_4006_000028    6156  4006  000028
# 946  spanish    101_567_000295     101   567  000295
#
# [947 rows x 5 columns]

# %%
# metainfo.txt (um para cada idioma): "gender", "title"
df_metainfo = pd.DataFrame()
for language in df_audios["language"].unique():
    metainfo_path = os.path.join(LANGUAGE_PATH, "metainfo.txt").format(language)
    df_aux = pd.read_csv(metainfo_path, sep="|", header=0, encoding="utf-8", dtype='str')
    df_aux.columns = df_aux.columns.str.strip().str.lower()
    df_aux["language"] = language
    df_metainfo = pd.concat([df_metainfo, df_aux])

df_metainfo = df_metainfo.apply(lambda x : x.str.strip())
df_metainfo = df_metainfo.rename(columns={"book id":"book"})

# %%
df_metainfo.isna().sum()
# Out:
# speaker      0
# gender       0
# partition    0
# minutes      0
# book         0
# title        0
# chapter      0
# language     0
# dtype: int64

# %%
df_metainfo.head(2)
# Out:
#   speaker gender partition minutes   book                     title  \
# 0    6001      F     train  31.716  10011  Piacevoli Notti, Libro 1
# 1    6001      F     train  25.961  10011  Piacevoli Notti, Libro 1
#
#                    chapter language
# 0   Notte Prima: FAVOLA II  italian
# 1  Notte Quinta: FAVOLA II  italian

# %%
df_audios = pd.merge(
    df_audios,
    df_metainfo[['speaker', 'gender', 'book', 'title', 'language']],
    on=["language", "speaker", "book"],
    how="left",
    indicator=True
)
print(df_audios["_merge"].value_counts())
df_audios = df_audios.drop_duplicates().reset_index(drop=True)
print(df_audios["_merge"].value_counts())
df_audios = df_audios.drop(columns=["_merge"])
# Out:
# both          8841
# left_only        0
# right_only       0
# Name: _merge, dtype: int64
# both          947
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
df_audios
# Out:
#     language                id speaker  book segment gender  \
# 0    italian  8828_8610_000510    8828  8610  000510      F
# 1    italian    659_547_000790     659   547  000790      F
# 2    italian    643_529_000116     643   529  000116      F
# 3    italian  8828_8610_000321    8828  8610  000321      F
# 4    italian    659_547_000279     659   547  000279      F
# ..       ...               ...     ...   ...     ...    ...
# 942  spanish  6156_4006_000020    6156  4006  000020      M
# 943  spanish    101_567_000034     101   567  000034      M
# 944  spanish  8881_8550_000536    8881  8550  000536      M
# 945  spanish  6156_4006_000028    6156  4006  000028      M
# 946  spanish    101_567_000295     101   567  000295      M
#
#                                         title
# 0    Novelle per un Anno, vol. 12: Il Viaggio
# 1                      Avventure di Pinocchio
# 2                             Divina Commedia
# 3    Novelle per un Anno, vol. 12: Il Viaggio
# 4                      Avventure di Pinocchio
# ..                                        ...
# 942                 Condenada y Otros Cuentos
# 943                             Don Quijote 1
# 944                   Aprendiz de Conspirador
# 945                 Condenada y Otros Cuentos
# 946                             Don Quijote 1
#
# [947 rows x 7 columns]

# %% [markdown]
# Qual é a proporção de áudios masculinos e femininos por idioma?

# %%
men_women_proportion = df_audios.groupby("language")["gender"].value_counts().rename("counts").to_frame().reset_index()
men_women_proportion = men_women_proportion.pivot(index="language", columns="gender", values="counts")
men_women_proportion["total"] = men_women_proportion["M"] + men_women_proportion["F"]
men_women_proportion["ptc_women"] = np.round(men_women_proportion["F"] / men_women_proportion["total"] * 100, 2)
men_women_proportion["ptc_men"] = np.round(men_women_proportion["M"] / men_women_proportion["total"] * 100, 2)
men_women_proportion = men_women_proportion[['F', 'M', 'ptc_women', 'ptc_men', 'total']]
men_women_proportion
# Out:
# gender        F    M  ptc_women  ptc_men  total
# language
# italian     116  124      48.33    51.67    240
# polish      118  120      49.58    50.42    238
# portuguese  119  117      50.42    49.58    236
# spanish     115  118      49.36    50.64    233

# %%
# audio
audios = []
lengths = []
srs = []
for i, row in df_audios.iterrows():
    print(i)
    print("Idioma: {}".format(row["language"]))
    print("ID: {}".format(row["id"]))
    
    audio_path = AUDIO_PATH.format(row["language"], row["speaker"], row["book"], row["id"])
    audio, sr = librosa.load(audio_path, sr=16000, mono=True) # sr é fornecido no README.md
    length = len(audio)
    print("Leu {} com sucesso!".format(audio_path))
    
    audios.append(audio)
    srs.append(sr)
    lengths.append(length)
    
    print()
# Out:
# 0
# Idioma: italian
# ID: 8828_8610_000510
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000510.flac com sucesso!
#
# 1
# Idioma: italian
# ID: 659_547_000790
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000790.flac com sucesso!
#
# 2
# Idioma: italian
# ID: 643_529_000116
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000116.flac com sucesso!
#
# 3
# Idioma: italian
# ID: 8828_8610_000321
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000321.flac com sucesso!
#
# 4
# Idioma: italian
# ID: 659_547_000279
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000279.flac com sucesso!
#
# 5
# Idioma: italian
# ID: 643_529_000078
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000078.flac com sucesso!
#
# 6
# Idioma: italian
# ID: 8828_8610_000293
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000293.flac com sucesso!
#
# 7
# Idioma: italian
# ID: 659_547_000214
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000214.flac com sucesso!
#
# 8
# Idioma: italian
# ID: 643_529_000095
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000095.flac com sucesso!
#
# 9
# Idioma: italian
# ID: 8828_8842_000080
# Leu ../data/mls/mls_italian/train/audio/8828/8842/8828_8842_000080.flac com sucesso!
#
# 10
# Idioma: italian
# ID: 659_656_000050
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000050.flac com sucesso!
#
# 11
# Idioma: italian
# ID: 643_529_000109
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000109.flac com sucesso!
#
# 12
# Idioma: italian
# ID: 8828_8610_000300
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000300.flac com sucesso!
#
# 13
# Idioma: italian
# ID: 659_656_000083
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000083.flac com sucesso!
#
# 14
# Idioma: italian
# ID: 643_529_000093
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000093.flac com sucesso!
#
# 15
# Idioma: italian
# ID: 8828_8842_000047
# Leu ../data/mls/mls_italian/train/audio/8828/8842/8828_8842_000047.flac com sucesso!
#
# 16
# Idioma: italian
# ID: 659_547_000897
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000897.flac com sucesso!
#
# 17
# Idioma: italian
# ID: 643_529_000231
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000231.flac com sucesso!
#
# 18
# Idioma: italian
# ID: 8828_8610_000574
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000574.flac com sucesso!
#
# 19
# Idioma: italian
# ID: 659_656_000597
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000597.flac com sucesso!
#
# 20
# Idioma: italian
# ID: 9772_11418_000005
# Leu ../data/mls/mls_italian/train/audio/9772/11418/9772_11418_000005.flac com sucesso!
#
# 21
# Idioma: italian
# ID: 1989_3305_000093
# Leu ../data/mls/mls_italian/train/audio/1989/3305/1989_3305_000093.flac com sucesso!
#
# 22
# Idioma: italian
# ID: 4261_2532_000016
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000016.flac com sucesso!
#
# 23
# Idioma: italian
# ID: 9772_8906_000050
# Leu ../data/mls/mls_italian/train/audio/9772/8906/9772_8906_000050.flac com sucesso!
#
# 24
# Idioma: italian
# ID: 1989_7240_000431
# Leu ../data/mls/mls_italian/train/audio/1989/7240/1989_7240_000431.flac com sucesso!
#
# 25
# Idioma: italian
# ID: 4261_2532_000010
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000010.flac com sucesso!
#
# 26
# Idioma: italian
# ID: 9772_10624_000643
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000643.flac com sucesso!
#
# 27
# Idioma: italian
# ID: 1989_4918_000215
# Leu ../data/mls/mls_italian/train/audio/1989/4918/1989_4918_000215.flac com sucesso!
#
# 28
# Idioma: italian
# ID: 4261_2532_000017
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000017.flac com sucesso!
#
# 29
# Idioma: italian
# ID: 9772_11418_000100
# Leu ../data/mls/mls_italian/train/audio/9772/11418/9772_11418_000100.flac com sucesso!
#
# 30
# Idioma: italian
# ID: 1989_4918_000121
# Leu ../data/mls/mls_italian/train/audio/1989/4918/1989_4918_000121.flac com sucesso!
#
# 31
# Idioma: italian
# ID: 4261_2532_000006
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000006.flac com sucesso!
#
# 32
# Idioma: italian
# ID: 9772_10624_000522
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000522.flac com sucesso!
#
# 33
# Idioma: italian
# ID: 1989_7240_000786
# Leu ../data/mls/mls_italian/train/audio/1989/7240/1989_7240_000786.flac com sucesso!
#
# 34
# Idioma: italian
# ID: 4261_2532_000014
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000014.flac com sucesso!
#
# 35
# Idioma: italian
# ID: 9772_10011_000032
# Leu ../data/mls/mls_italian/train/audio/9772/10011/9772_10011_000032.flac com sucesso!
#
# 36
# Idioma: italian
# ID: 1989_1590_000127
# Leu ../data/mls/mls_italian/train/audio/1989/1590/1989_1590_000127.flac com sucesso!
#
# 37
# Idioma: italian
# ID: 4261_2532_000012
# Leu ../data/mls/mls_italian/train/audio/4261/2532/4261_2532_000012.flac com sucesso!
#
# 38
# Idioma: italian
# ID: 9772_9630_000038
# Leu ../data/mls/mls_italian/train/audio/9772/9630/9772_9630_000038.flac com sucesso!
#
# 39
# Idioma: italian
# ID: 1989_7240_000618
# Leu ../data/mls/mls_italian/train/audio/1989/7240/1989_7240_000618.flac com sucesso!
#
# 40
# Idioma: italian
# ID: 7230_6241_000161
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000161.flac com sucesso!
#
# 41
# Idioma: italian
# ID: 10179_9630_000004
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000004.flac com sucesso!
#
# 42
# Idioma: italian
# ID: 659_547_000901
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000901.flac com sucesso!
#
# 43
# Idioma: italian
# ID: 7230_6241_000115
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000115.flac com sucesso!
#
# 44
# Idioma: italian
# ID: 10179_9630_000009
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000009.flac com sucesso!
#
# 45
# Idioma: italian
# ID: 659_547_000895
# Leu ../data/mls/mls_italian/train/audio/659/547/659_547_000895.flac com sucesso!
#
# 46
# Idioma: italian
# ID: 7230_6241_000080
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000080.flac com sucesso!
#
# 47
# Idioma: italian
# ID: 10179_9630_000000
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000000.flac com sucesso!
#
# 48
# Idioma: italian
# ID: 659_656_000796
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000796.flac com sucesso!
#
# 49
# Idioma: italian
# ID: 7230_6241_000017
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000017.flac com sucesso!
#
# 50
# Idioma: italian
# ID: 10179_9630_000006
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000006.flac com sucesso!
#
# 51
# Idioma: italian
# ID: 659_656_000485
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000485.flac com sucesso!
#
# 52
# Idioma: italian
# ID: 7230_6241_000006
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000006.flac com sucesso!
#
# 53
# Idioma: italian
# ID: 10179_9630_000012
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000012.flac com sucesso!
#
# 54
# Idioma: italian
# ID: 659_2012_000068
# Leu ../data/mls/mls_italian/train/audio/659/2012/659_2012_000068.flac com sucesso!
#
# 55
# Idioma: italian
# ID: 7230_6241_000088
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000088.flac com sucesso!
#
# 56
# Idioma: italian
# ID: 10179_9630_000008
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000008.flac com sucesso!
#
# 57
# Idioma: italian
# ID: 659_656_000304
# Leu ../data/mls/mls_italian/train/audio/659/656/659_656_000304.flac com sucesso!
#
# 58
# Idioma: italian
# ID: 7230_6241_000064
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000064.flac com sucesso!
#
# 59
# Idioma: italian
# ID: 10179_9630_000010
# Leu ../data/mls/mls_italian/train/audio/10179/9630/10179_9630_000010.flac com sucesso!
#
# 60
# Idioma: italian
# ID: 6299_5281_000177
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000177.flac com sucesso!
#
# 61
# Idioma: italian
# ID: 4705_4125_000064
# Leu ../data/mls/mls_italian/train/audio/4705/4125/4705_4125_000064.flac com sucesso!
#
# 62
# Idioma: italian
# ID: 1595_3627_000736
# Leu ../data/mls/mls_italian/train/audio/1595/3627/1595_3627_000736.flac com sucesso!
#
# 63
# Idioma: italian
# ID: 6299_5281_000287
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000287.flac com sucesso!
#
# 64
# Idioma: italian
# ID: 4705_9630_000054
# Leu ../data/mls/mls_italian/train/audio/4705/9630/4705_9630_000054.flac com sucesso!
#
# 65
# Idioma: italian
# ID: 1595_2012_000352
# Leu ../data/mls/mls_italian/train/audio/1595/2012/1595_2012_000352.flac com sucesso!
#
# 66
# Idioma: italian
# ID: 6299_5281_000191
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000191.flac com sucesso!
#
# 67
# Idioma: italian
# ID: 4705_4125_000220
# Leu ../data/mls/mls_italian/train/audio/4705/4125/4705_4125_000220.flac com sucesso!
#
# 68
# Idioma: italian
# ID: 1595_2012_000787
# Leu ../data/mls/mls_italian/train/audio/1595/2012/1595_2012_000787.flac com sucesso!
#
# 69
# Idioma: italian
# ID: 6299_5281_000132
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000132.flac com sucesso!
#
# 70
# Idioma: italian
# ID: 4705_4125_000207
# Leu ../data/mls/mls_italian/train/audio/4705/4125/4705_4125_000207.flac com sucesso!
#
# 71
# Idioma: italian
# ID: 1595_4194_000519
# Leu ../data/mls/mls_italian/train/audio/1595/4194/1595_4194_000519.flac com sucesso!
#
# 72
# Idioma: italian
# ID: 6299_5281_000283
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000283.flac com sucesso!
#
# 73
# Idioma: italian
# ID: 4705_9630_000143
# Leu ../data/mls/mls_italian/train/audio/4705/9630/4705_9630_000143.flac com sucesso!
#
# 74
# Idioma: italian
# ID: 1595_3311_000265
# Leu ../data/mls/mls_italian/train/audio/1595/3311/1595_3311_000265.flac com sucesso!
#
# 75
# Idioma: italian
# ID: 6299_5281_000306
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000306.flac com sucesso!
#
# 76
# Idioma: italian
# ID: 4705_9630_000032
# Leu ../data/mls/mls_italian/train/audio/4705/9630/4705_9630_000032.flac com sucesso!
#
# 77
# Idioma: italian
# ID: 1595_4194_000588
# Leu ../data/mls/mls_italian/train/audio/1595/4194/1595_4194_000588.flac com sucesso!
#
# 78
# Idioma: italian
# ID: 6299_5281_000026
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000026.flac com sucesso!
#
# 79
# Idioma: italian
# ID: 4705_9630_000122
# Leu ../data/mls/mls_italian/train/audio/4705/9630/4705_9630_000122.flac com sucesso!
#
# 80
# Idioma: italian
# ID: 1595_3627_001313
# Leu ../data/mls/mls_italian/train/audio/1595/3627/1595_3627_001313.flac com sucesso!
#
# 81
# Idioma: italian
# ID: 7230_6241_000105
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000105.flac com sucesso!
#
# 82
# Idioma: italian
# ID: 643_529_000097
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000097.flac com sucesso!
#
# 83
# Idioma: italian
# ID: 8842_8795_000166
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000166.flac com sucesso!
#
# 84
# Idioma: italian
# ID: 7230_6241_000021
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000021.flac com sucesso!
#
# 85
# Idioma: italian
# ID: 643_529_000050
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000050.flac com sucesso!
#
# 86
# Idioma: italian
# ID: 8842_8795_000115
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000115.flac com sucesso!
#
# 87
# Idioma: italian
# ID: 7230_6241_000111
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000111.flac com sucesso!
#
# 88
# Idioma: italian
# ID: 643_529_000221
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000221.flac com sucesso!
#
# 89
# Idioma: italian
# ID: 8842_8795_000492
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000492.flac com sucesso!
#
# 90
# Idioma: italian
# ID: 7230_6241_000075
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000075.flac com sucesso!
#
# 91
# Idioma: italian
# ID: 643_529_000217
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000217.flac com sucesso!
#
# 92
# Idioma: italian
# ID: 8842_8610_000042
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000042.flac com sucesso!
#
# 93
# Idioma: italian
# ID: 7230_6241_000039
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000039.flac com sucesso!
#
# 94
# Idioma: italian
# ID: 643_529_000140
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000140.flac com sucesso!
#
# 95
# Idioma: italian
# ID: 8842_8795_000125
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000125.flac com sucesso!
#
# 96
# Idioma: italian
# ID: 7230_6241_000147
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000147.flac com sucesso!
#
# 97
# Idioma: italian
# ID: 643_529_000222
# Leu ../data/mls/mls_italian/train/audio/643/529/643_529_000222.flac com sucesso!
#
# 98
# Idioma: italian
# ID: 8842_8610_000072
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000072.flac com sucesso!
#
# 99
# Idioma: italian
# ID: 7230_6241_000152
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000152.flac com sucesso!
#
# 100
# Idioma: italian
# ID: 1989_4918_000570
# Leu ../data/mls/mls_italian/train/audio/1989/4918/1989_4918_000570.flac com sucesso!
#
# 101
# Idioma: italian
# ID: 2019_3594_000508
# Leu ../data/mls/mls_italian/train/audio/2019/3594/2019_3594_000508.flac com sucesso!
#
# 102
# Idioma: italian
# ID: 12804_11418_000185
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000185.flac com sucesso!
#
# 103
# Idioma: italian
# ID: 1989_4918_000522
# Leu ../data/mls/mls_italian/train/audio/1989/4918/1989_4918_000522.flac com sucesso!
#
# 104
# Idioma: italian
# ID: 2019_1577_001386
# Leu ../data/mls/mls_italian/train/audio/2019/1577/2019_1577_001386.flac com sucesso!
#
# 105
# Idioma: italian
# ID: 12804_11418_000291
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000291.flac com sucesso!
#
# 106
# Idioma: italian
# ID: 1989_7240_000537
# Leu ../data/mls/mls_italian/train/audio/1989/7240/1989_7240_000537.flac com sucesso!
#
# 107
# Idioma: italian
# ID: 2019_1577_000849
# Leu ../data/mls/mls_italian/train/audio/2019/1577/2019_1577_000849.flac com sucesso!
#
# 108
# Idioma: italian
# ID: 12804_11418_000072
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000072.flac com sucesso!
#
# 109
# Idioma: italian
# ID: 1989_4918_000505
# Leu ../data/mls/mls_italian/train/audio/1989/4918/1989_4918_000505.flac com sucesso!
#
# 110
# Idioma: italian
# ID: 2019_1577_000040
# Leu ../data/mls/mls_italian/train/audio/2019/1577/2019_1577_000040.flac com sucesso!
#
# 111
# Idioma: italian
# ID: 12804_11418_000235
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000235.flac com sucesso!
#
# 112
# Idioma: italian
# ID: 1989_3305_000272
# Leu ../data/mls/mls_italian/train/audio/1989/3305/1989_3305_000272.flac com sucesso!
#
# 113
# Idioma: italian
# ID: 2019_1577_001299
# Leu ../data/mls/mls_italian/train/audio/2019/1577/2019_1577_001299.flac com sucesso!
#
# 114
# Idioma: italian
# ID: 12804_11418_000245
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000245.flac com sucesso!
#
# 115
# Idioma: italian
# ID: 1989_1590_000100
# Leu ../data/mls/mls_italian/train/audio/1989/1590/1989_1590_000100.flac com sucesso!
#
# 116
# Idioma: italian
# ID: 2019_3594_000172
# Leu ../data/mls/mls_italian/train/audio/2019/3594/2019_3594_000172.flac com sucesso!
#
# 117
# Idioma: italian
# ID: 12804_9630_000009
# Leu ../data/mls/mls_italian/train/audio/12804/9630/12804_9630_000009.flac com sucesso!
#
# 118
# Idioma: italian
# ID: 1989_1590_000030
# Leu ../data/mls/mls_italian/train/audio/1989/1590/1989_1590_000030.flac com sucesso!
#
# 119
# Idioma: italian
# ID: 2019_3594_000470
# Leu ../data/mls/mls_italian/train/audio/2019/3594/2019_3594_000470.flac com sucesso!
#
# 120
# Idioma: italian
# ID: 12804_11418_000190
# Leu ../data/mls/mls_italian/train/audio/12804/11418/12804_11418_000190.flac com sucesso!
#
# 121
# Idioma: italian
# ID: 8842_8610_000094
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000094.flac com sucesso!
#
# 122
# Idioma: italian
# ID: 8461_7877_000005
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000005.flac com sucesso!
#
# 123
# Idioma: italian
# ID: 6807_7050_001410
# Leu ../data/mls/mls_italian/train/audio/6807/7050/6807_7050_001410.flac com sucesso!
#
# 124
# Idioma: italian
# ID: 8842_8795_000243
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000243.flac com sucesso!
#
# 125
# Idioma: italian
# ID: 8461_7877_000147
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000147.flac com sucesso!
#
# 126
# Idioma: italian
# ID: 6807_7050_000547
# Leu ../data/mls/mls_italian/train/audio/6807/7050/6807_7050_000547.flac com sucesso!
#
# 127
# Idioma: italian
# ID: 8842_8610_000260
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000260.flac com sucesso!
#
# 128
# Idioma: italian
# ID: 8461_7877_000157
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000157.flac com sucesso!
#
# 129
# Idioma: italian
# ID: 6807_5862_000440
# Leu ../data/mls/mls_italian/train/audio/6807/5862/6807_5862_000440.flac com sucesso!
#
# 130
# Idioma: italian
# ID: 8842_8795_000296
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000296.flac com sucesso!
#
# 131
# Idioma: italian
# ID: 8461_7877_000035
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000035.flac com sucesso!
#
# 132
# Idioma: italian
# ID: 6807_7050_000750
# Leu ../data/mls/mls_italian/train/audio/6807/7050/6807_7050_000750.flac com sucesso!
#
# 133
# Idioma: italian
# ID: 8842_8795_000004
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000004.flac com sucesso!
#
# 134
# Idioma: italian
# ID: 8461_7877_000182
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000182.flac com sucesso!
#
# 135
# Idioma: italian
# ID: 6807_7050_001659
# Leu ../data/mls/mls_italian/train/audio/6807/7050/6807_7050_001659.flac com sucesso!
#
# 136
# Idioma: italian
# ID: 8842_8795_000172
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000172.flac com sucesso!
#
# 137
# Idioma: italian
# ID: 8461_7877_000220
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000220.flac com sucesso!
#
# 138
# Idioma: italian
# ID: 6807_7720_000251
# Leu ../data/mls/mls_italian/train/audio/6807/7720/6807_7720_000251.flac com sucesso!
#
# 139
# Idioma: italian
# ID: 8842_8610_000096
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000096.flac com sucesso!
#
# 140
# Idioma: italian
# ID: 8461_7877_000045
# Leu ../data/mls/mls_italian/train/audio/8461/7877/8461_7877_000045.flac com sucesso!
#
# 141
# Idioma: italian
# ID: 12598_9630_000036
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000036.flac com sucesso!
#
# 142
# Idioma: italian
# ID: 1595_5616_001101
# Leu ../data/mls/mls_italian/train/audio/1595/5616/1595_5616_001101.flac com sucesso!
#
# 143
# Idioma: italian
# ID: 644_2532_000345
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000345.flac com sucesso!
#
# 144
# Idioma: italian
# ID: 12598_9630_000011
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000011.flac com sucesso!
#
# 145
# Idioma: italian
# ID: 1595_5616_001019
# Leu ../data/mls/mls_italian/train/audio/1595/5616/1595_5616_001019.flac com sucesso!
#
# 146
# Idioma: italian
# ID: 644_2532_000231
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000231.flac com sucesso!
#
# 147
# Idioma: italian
# ID: 12598_9630_000006
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000006.flac com sucesso!
#
# 148
# Idioma: italian
# ID: 1595_3311_001171
# Leu ../data/mls/mls_italian/train/audio/1595/3311/1595_3311_001171.flac com sucesso!
#
# 149
# Idioma: italian
# ID: 644_2532_000252
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000252.flac com sucesso!
#
# 150
# Idioma: italian
# ID: 12598_9630_000004
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000004.flac com sucesso!
#
# 151
# Idioma: italian
# ID: 1595_3627_000959
# Leu ../data/mls/mls_italian/train/audio/1595/3627/1595_3627_000959.flac com sucesso!
#
# 152
# Idioma: italian
# ID: 644_2532_000061
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000061.flac com sucesso!
#
# 153
# Idioma: italian
# ID: 12598_9630_000024
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000024.flac com sucesso!
#
# 154
# Idioma: italian
# ID: 1595_5071_000131
# Leu ../data/mls/mls_italian/train/audio/1595/5071/1595_5071_000131.flac com sucesso!
#
# 155
# Idioma: italian
# ID: 644_2532_000321
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000321.flac com sucesso!
#
# 156
# Idioma: italian
# ID: 12598_9630_000000
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000000.flac com sucesso!
#
# 157
# Idioma: italian
# ID: 1595_5616_000434
# Leu ../data/mls/mls_italian/train/audio/1595/5616/1595_5616_000434.flac com sucesso!
#
# 158
# Idioma: italian
# ID: 644_2532_000029
# Leu ../data/mls/mls_italian/train/audio/644/2532/644_2532_000029.flac com sucesso!
#
# 159
# Idioma: italian
# ID: 12598_9630_000043
# Leu ../data/mls/mls_italian/train/audio/12598/9630/12598_9630_000043.flac com sucesso!
#
# 160
# Idioma: italian
# ID: 1595_4194_001795
# Leu ../data/mls/mls_italian/train/audio/1595/4194/1595_4194_001795.flac com sucesso!
#
# 161
# Idioma: italian
# ID: 4971_4125_000128
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000128.flac com sucesso!
#
# 162
# Idioma: italian
# ID: 166_529_000014
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000014.flac com sucesso!
#
# 163
# Idioma: italian
# ID: 7444_6815_000004
# Leu ../data/mls/mls_italian/train/audio/7444/6815/7444_6815_000004.flac com sucesso!
#
# 164
# Idioma: italian
# ID: 4971_4125_000121
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000121.flac com sucesso!
#
# 165
# Idioma: italian
# ID: 166_529_000117
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000117.flac com sucesso!
#
# 166
# Idioma: italian
# ID: 7444_6815_000091
# Leu ../data/mls/mls_italian/train/audio/7444/6815/7444_6815_000091.flac com sucesso!
#
# 167
# Idioma: italian
# ID: 4971_4125_000234
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000234.flac com sucesso!
#
# 168
# Idioma: italian
# ID: 166_529_000126
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000126.flac com sucesso!
#
# 169
# Idioma: italian
# ID: 7444_6815_000100
# Leu ../data/mls/mls_italian/train/audio/7444/6815/7444_6815_000100.flac com sucesso!
#
# 170
# Idioma: italian
# ID: 4971_4125_000208
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000208.flac com sucesso!
#
# 171
# Idioma: italian
# ID: 166_529_000102
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000102.flac com sucesso!
#
# 172
# Idioma: italian
# ID: 7444_6589_000131
# Leu ../data/mls/mls_italian/train/audio/7444/6589/7444_6589_000131.flac com sucesso!
#
# 173
# Idioma: italian
# ID: 4971_4125_000232
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000232.flac com sucesso!
#
# 174
# Idioma: italian
# ID: 166_529_000092
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000092.flac com sucesso!
#
# 175
# Idioma: italian
# ID: 7444_6815_000054
# Leu ../data/mls/mls_italian/train/audio/7444/6815/7444_6815_000054.flac com sucesso!
#
# 176
# Idioma: italian
# ID: 4971_4125_000033
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000033.flac com sucesso!
#
# 177
# Idioma: italian
# ID: 166_529_000081
# Leu ../data/mls/mls_italian/train/audio/166/529/166_529_000081.flac com sucesso!
#
# 178
# Idioma: italian
# ID: 7444_6589_000013
# Leu ../data/mls/mls_italian/train/audio/7444/6589/7444_6589_000013.flac com sucesso!
#
# 179
# Idioma: italian
# ID: 4971_4125_000044
# Leu ../data/mls/mls_italian/train/audio/4971/4125/4971_4125_000044.flac com sucesso!
#
# 180
# Idioma: italian
# ID: 5010_4125_000042
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000042.flac com sucesso!
#
# 181
# Idioma: italian
# ID: 6299_5281_000198
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000198.flac com sucesso!
#
# 182
# Idioma: italian
# ID: 9772_11418_000091
# Leu ../data/mls/mls_italian/train/audio/9772/11418/9772_11418_000091.flac com sucesso!
#
# 183
# Idioma: italian
# ID: 5010_4125_000020
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000020.flac com sucesso!
#
# 184
# Idioma: italian
# ID: 6299_5281_000103
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000103.flac com sucesso!
#
# 185
# Idioma: italian
# ID: 9772_10624_000320
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000320.flac com sucesso!
#
# 186
# Idioma: italian
# ID: 5010_4125_000024
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000024.flac com sucesso!
#
# 187
# Idioma: italian
# ID: 6299_5281_000138
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000138.flac com sucesso!
#
# 188
# Idioma: italian
# ID: 9772_10011_000025
# Leu ../data/mls/mls_italian/train/audio/9772/10011/9772_10011_000025.flac com sucesso!
#
# 189
# Idioma: italian
# ID: 5010_4125_000213
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000213.flac com sucesso!
#
# 190
# Idioma: italian
# ID: 6299_5281_000002
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000002.flac com sucesso!
#
# 191
# Idioma: italian
# ID: 9772_10624_000120
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000120.flac com sucesso!
#
# 192
# Idioma: italian
# ID: 5010_4125_000143
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000143.flac com sucesso!
#
# 193
# Idioma: italian
# ID: 6299_5281_000302
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000302.flac com sucesso!
#
# 194
# Idioma: italian
# ID: 9772_10624_000207
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000207.flac com sucesso!
#
# 195
# Idioma: italian
# ID: 5010_4125_000096
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000096.flac com sucesso!
#
# 196
# Idioma: italian
# ID: 6299_5281_000054
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000054.flac com sucesso!
#
# 197
# Idioma: italian
# ID: 9772_11418_000156
# Leu ../data/mls/mls_italian/train/audio/9772/11418/9772_11418_000156.flac com sucesso!
#
# 198
# Idioma: italian
# ID: 5010_4125_000160
# Leu ../data/mls/mls_italian/train/audio/5010/4125/5010_4125_000160.flac com sucesso!
#
# 199
# Idioma: italian
# ID: 6299_5281_000221
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000221.flac com sucesso!
#
# 200
# Idioma: italian
# ID: 9772_10624_000191
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000191.flac com sucesso!
#
# 201
# Idioma: italian
# ID: 7230_6241_000068
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000068.flac com sucesso!
#
# 202
# Idioma: italian
# ID: 8842_8610_000165
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000165.flac com sucesso!
#
# 203
# Idioma: italian
# ID: 8828_8610_000603
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000603.flac com sucesso!
#
# 204
# Idioma: italian
# ID: 7230_6241_000043
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000043.flac com sucesso!
#
# 205
# Idioma: italian
# ID: 8842_8795_000356
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000356.flac com sucesso!
#
# 206
# Idioma: italian
# ID: 8828_7877_000015
# Leu ../data/mls/mls_italian/train/audio/8828/7877/8828_7877_000015.flac com sucesso!
#
# 207
# Idioma: italian
# ID: 7230_6241_000033
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000033.flac com sucesso!
#
# 208
# Idioma: italian
# ID: 8842_8610_000167
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000167.flac com sucesso!
#
# 209
# Idioma: italian
# ID: 8828_7877_000113
# Leu ../data/mls/mls_italian/train/audio/8828/7877/8828_7877_000113.flac com sucesso!
#
# 210
# Idioma: italian
# ID: 7230_6241_000110
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000110.flac com sucesso!
#
# 211
# Idioma: italian
# ID: 8842_8610_000168
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000168.flac com sucesso!
#
# 212
# Idioma: italian
# ID: 8828_8610_000229
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000229.flac com sucesso!
#
# 213
# Idioma: italian
# ID: 7230_6241_000031
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000031.flac com sucesso!
#
# 214
# Idioma: italian
# ID: 8842_8610_000178
# Leu ../data/mls/mls_italian/train/audio/8842/8610/8842_8610_000178.flac com sucesso!
#
# 215
# Idioma: italian
# ID: 8828_8610_000065
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000065.flac com sucesso!
#
# 216
# Idioma: italian
# ID: 7230_6241_000132
# Leu ../data/mls/mls_italian/train/audio/7230/6241/7230_6241_000132.flac com sucesso!
#
# 217
# Idioma: italian
# ID: 8842_8795_000443
# Leu ../data/mls/mls_italian/train/audio/8842/8795/8842_8795_000443.flac com sucesso!
#
# 218
# Idioma: italian
# ID: 8828_8610_000202
# Leu ../data/mls/mls_italian/train/audio/8828/8610/8828_8610_000202.flac com sucesso!
#
# 219
# Idioma: italian
# ID: 9772_8842_000091
# Leu ../data/mls/mls_italian/train/audio/9772/8842/9772_8842_000091.flac com sucesso!
#
# 220
# Idioma: italian
# ID: 6299_5281_000193
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000193.flac com sucesso!
#
# 221
# Idioma: italian
# ID: 10446_10415_000048
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000048.flac com sucesso!
#
# 222
# Idioma: italian
# ID: 9772_10624_000288
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000288.flac com sucesso!
#
# 223
# Idioma: italian
# ID: 6299_5281_000157
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000157.flac com sucesso!
#
# 224
# Idioma: italian
# ID: 10446_10415_001539
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_001539.flac com sucesso!
#
# 225
# Idioma: italian
# ID: 9772_8842_000256
# Leu ../data/mls/mls_italian/train/audio/9772/8842/9772_8842_000256.flac com sucesso!
#
# 226
# Idioma: italian
# ID: 6299_5281_000171
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000171.flac com sucesso!
#
# 227
# Idioma: italian
# ID: 10446_10415_000935
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000935.flac com sucesso!
#
# 228
# Idioma: italian
# ID: 9772_10011_000104
# Leu ../data/mls/mls_italian/train/audio/9772/10011/9772_10011_000104.flac com sucesso!
#
# 229
# Idioma: italian
# ID: 6299_5281_000070
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000070.flac com sucesso!
#
# 230
# Idioma: italian
# ID: 10446_10415_000597
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000597.flac com sucesso!
#
# 231
# Idioma: italian
# ID: 9772_8842_000172
# Leu ../data/mls/mls_italian/train/audio/9772/8842/9772_8842_000172.flac com sucesso!
#
# 232
# Idioma: italian
# ID: 6299_5281_000060
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000060.flac com sucesso!
#
# 233
# Idioma: italian
# ID: 10446_10415_000736
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000736.flac com sucesso!
#
# 234
# Idioma: italian
# ID: 9772_8842_000097
# Leu ../data/mls/mls_italian/train/audio/9772/8842/9772_8842_000097.flac com sucesso!
#
# 235
# Idioma: italian
# ID: 6299_5281_000233
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000233.flac com sucesso!
#
# 236
# Idioma: italian
# ID: 10446_10415_000111
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000111.flac com sucesso!
#
# 237
# Idioma: italian
# ID: 9772_10624_000567
# Leu ../data/mls/mls_italian/train/audio/9772/10624/9772_10624_000567.flac com sucesso!
#
# 238
# Idioma: italian
# ID: 6299_5281_000220
# Leu ../data/mls/mls_italian/train/audio/6299/5281/6299_5281_000220.flac com sucesso!
#
# 239
# Idioma: italian
# ID: 10446_10415_000971
# Leu ../data/mls/mls_italian/train/audio/10446/10415/10446_10415_000971.flac com sucesso!
#
# 240
# Idioma: polish
# ID: 4228_1447_000021
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000021.flac com sucesso!
#
# 241
# Idioma: polish
# ID: 7014_6288_000494
# Leu ../data/mls/mls_polish/train/audio/7014/6288/7014_6288_000494.flac com sucesso!
#
# 242
# Idioma: polish
# ID: 1329_1447_000021
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000021.flac com sucesso!
#
# 243
# Idioma: polish
# ID: 4228_1447_000023
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000023.flac com sucesso!
#
# 244
# Idioma: polish
# ID: 7014_6834_002582
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_002582.flac com sucesso!
#
# 245
# Idioma: polish
# ID: 1329_1447_000014
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000014.flac com sucesso!
#
# 246
# Idioma: polish
# ID: 4228_1447_000018
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000018.flac com sucesso!
#
# 247
# Idioma: polish
# ID: 7014_6834_003205
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_003205.flac com sucesso!
#
# 248
# Idioma: polish
# ID: 1329_1447_000022
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000022.flac com sucesso!
#
# 249
# Idioma: polish
# ID: 4228_1447_000008
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000008.flac com sucesso!
#
# 250
# Idioma: polish
# ID: 7014_6834_002786
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_002786.flac com sucesso!
#
# 251
# Idioma: polish
# ID: 1329_1447_000013
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000013.flac com sucesso!
#
# 252
# Idioma: polish
# ID: 4228_1447_000005
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000005.flac com sucesso!
#
# 253
# Idioma: polish
# ID: 7014_6288_000347
# Leu ../data/mls/mls_polish/train/audio/7014/6288/7014_6288_000347.flac com sucesso!
#
# 254
# Idioma: polish
# ID: 1329_1447_000029
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000029.flac com sucesso!
#
# 255
# Idioma: polish
# ID: 4228_1447_000036
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000036.flac com sucesso!
#
# 256
# Idioma: polish
# ID: 7014_6254_000463
# Leu ../data/mls/mls_polish/train/audio/7014/6254/7014_6254_000463.flac com sucesso!
#
# 257
# Idioma: polish
# ID: 1329_1447_000001
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000001.flac com sucesso!
#
# 258
# Idioma: polish
# ID: 1890_1447_000006
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000006.flac com sucesso!
#
# 259
# Idioma: polish
# ID: 3553_1447_000005
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000005.flac com sucesso!
#
# 260
# Idioma: polish
# ID: 6892_10920_000862
# Leu ../data/mls/mls_polish/train/audio/6892/10920/6892_10920_000862.flac com sucesso!
#
# 261
# Idioma: polish
# ID: 1890_1447_000026
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000026.flac com sucesso!
#
# 262
# Idioma: polish
# ID: 3553_1447_000008
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000008.flac com sucesso!
#
# 263
# Idioma: polish
# ID: 6892_10615_000709
# Leu ../data/mls/mls_polish/train/audio/6892/10615/6892_10615_000709.flac com sucesso!
#
# 264
# Idioma: polish
# ID: 1890_1447_000029
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000029.flac com sucesso!
#
# 265
# Idioma: polish
# ID: 3553_1447_000012
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000012.flac com sucesso!
#
# 266
# Idioma: polish
# ID: 6892_8764_001280
# Leu ../data/mls/mls_polish/train/audio/6892/8764/6892_8764_001280.flac com sucesso!
#
# 267
# Idioma: polish
# ID: 1890_1447_000015
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000015.flac com sucesso!
#
# 268
# Idioma: polish
# ID: 3553_1447_000007
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000007.flac com sucesso!
#
# 269
# Idioma: polish
# ID: 6892_8764_001779
# Leu ../data/mls/mls_polish/train/audio/6892/8764/6892_8764_001779.flac com sucesso!
#
# 270
# Idioma: polish
# ID: 1890_1447_000030
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000030.flac com sucesso!
#
# 271
# Idioma: polish
# ID: 3553_1447_000003
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000003.flac com sucesso!
#
# 272
# Idioma: polish
# ID: 6892_10674_001882
# Leu ../data/mls/mls_polish/train/audio/6892/10674/6892_10674_001882.flac com sucesso!
#
# 273
# Idioma: polish
# ID: 1890_1447_000028
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000028.flac com sucesso!
#
# 274
# Idioma: polish
# ID: 3553_1447_000015
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000015.flac com sucesso!
#
# 275
# Idioma: polish
# ID: 6892_10615_000555
# Leu ../data/mls/mls_polish/train/audio/6892/10615/6892_10615_000555.flac com sucesso!
#
# 276
# Idioma: polish
# ID: 1890_1447_000004
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000004.flac com sucesso!
#
# 277
# Idioma: polish
# ID: 3553_1447_000013
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000013.flac com sucesso!
#
# 278
# Idioma: polish
# ID: 4228_1447_000022
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000022.flac com sucesso!
#
# 279
# Idioma: polish
# ID: 1329_1447_000028
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000028.flac com sucesso!
#
# 280
# Idioma: polish
# ID: 7014_6834_000084
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_000084.flac com sucesso!
#
# 281
# Idioma: polish
# ID: 4228_1447_000041
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000041.flac com sucesso!
#
# 282
# Idioma: polish
# ID: 1329_1447_000003
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000003.flac com sucesso!
#
# 283
# Idioma: polish
# ID: 7014_6254_000032
# Leu ../data/mls/mls_polish/train/audio/7014/6254/7014_6254_000032.flac com sucesso!
#
# 284
# Idioma: polish
# ID: 4228_1447_000048
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000048.flac com sucesso!
#
# 285
# Idioma: polish
# ID: 1329_1447_000015
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000015.flac com sucesso!
#
# 286
# Idioma: polish
# ID: 7014_6834_002321
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_002321.flac com sucesso!
#
# 287
# Idioma: polish
# ID: 4228_1447_000037
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000037.flac com sucesso!
#
# 288
# Idioma: polish
# ID: 1329_1447_000007
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000007.flac com sucesso!
#
# 289
# Idioma: polish
# ID: 7014_6834_003253
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_003253.flac com sucesso!
#
# 290
# Idioma: polish
# ID: 4228_1447_000031
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000031.flac com sucesso!
#
# 291
# Idioma: polish
# ID: 1329_1447_000006
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000006.flac com sucesso!
#
# 292
# Idioma: polish
# ID: 7014_6834_003203
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_003203.flac com sucesso!
#
# 293
# Idioma: polish
# ID: 4228_1447_000035
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000035.flac com sucesso!
#
# 294
# Idioma: polish
# ID: 1329_1447_000032
# Leu ../data/mls/mls_polish/train/audio/1329/1447/1329_1447_000032.flac com sucesso!
#
# 295
# Idioma: polish
# ID: 7014_6834_000994
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_000994.flac com sucesso!
#
# 296
# Idioma: polish
# ID: 4228_1447_000046
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000046.flac com sucesso!
#
# 297
# Idioma: polish
# ID: 3283_1447_000011
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000011.flac com sucesso!
#
# 298
# Idioma: polish
# ID: 3553_1447_000011
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000011.flac com sucesso!
#
# 299
# Idioma: polish
# ID: 1890_1447_000008
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000008.flac com sucesso!
#
# 300
# Idioma: polish
# ID: 3283_1447_000004
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000004.flac com sucesso!
#
# 301
# Idioma: polish
# ID: 3553_1447_000010
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000010.flac com sucesso!
#
# 302
# Idioma: polish
# ID: 1890_1447_000032
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000032.flac com sucesso!
#
# 303
# Idioma: polish
# ID: 3283_1447_000008
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000008.flac com sucesso!
#
# 304
# Idioma: polish
# ID: 3553_1447_000004
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000004.flac com sucesso!
#
# 305
# Idioma: polish
# ID: 1890_1447_000038
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000038.flac com sucesso!
#
# 306
# Idioma: polish
# ID: 3283_1447_000009
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000009.flac com sucesso!
#
# 307
# Idioma: polish
# ID: 3553_1447_000000
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000000.flac com sucesso!
#
# 308
# Idioma: polish
# ID: 1890_1447_000022
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000022.flac com sucesso!
#
# 309
# Idioma: polish
# ID: 3283_1447_000001
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000001.flac com sucesso!
#
# 310
# Idioma: polish
# ID: 3553_1447_000006
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000006.flac com sucesso!
#
# 311
# Idioma: polish
# ID: 1890_1447_000025
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000025.flac com sucesso!
#
# 312
# Idioma: polish
# ID: 3283_1447_000016
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000016.flac com sucesso!
#
# 313
# Idioma: polish
# ID: 3553_1447_000009
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000009.flac com sucesso!
#
# 314
# Idioma: polish
# ID: 1890_1447_000020
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000020.flac com sucesso!
#
# 315
# Idioma: polish
# ID: 3283_1447_000002
# Leu ../data/mls/mls_polish/train/audio/3283/1447/3283_1447_000002.flac com sucesso!
#
# 316
# Idioma: polish
# ID: 3553_1447_000014
# Leu ../data/mls/mls_polish/train/audio/3553/1447/3553_1447_000014.flac com sucesso!
#
# 317
# Idioma: polish
# ID: 1890_1447_000031
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000031.flac com sucesso!
#
# 318
# Idioma: polish
# ID: 1636_1447_000036
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000036.flac com sucesso!
#
# 319
# Idioma: polish
# ID: 4228_1447_000010
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000010.flac com sucesso!
#
# 320
# Idioma: polish
# ID: 7014_6288_000619
# Leu ../data/mls/mls_polish/train/audio/7014/6288/7014_6288_000619.flac com sucesso!
#
# 321
# Idioma: polish
# ID: 1636_1447_000034
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000034.flac com sucesso!
#
# 322
# Idioma: polish
# ID: 4228_1447_000013
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000013.flac com sucesso!
#
# 323
# Idioma: polish
# ID: 7014_6834_001000
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_001000.flac com sucesso!
#
# 324
# Idioma: polish
# ID: 1636_1447_000010
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000010.flac com sucesso!
#
# 325
# Idioma: polish
# ID: 4228_1447_000014
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000014.flac com sucesso!
#
# 326
# Idioma: polish
# ID: 7014_6834_004295
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_004295.flac com sucesso!
#
# 327
# Idioma: polish
# ID: 1636_1447_000015
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000015.flac com sucesso!
#
# 328
# Idioma: polish
# ID: 4228_1447_000000
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000000.flac com sucesso!
#
# 329
# Idioma: polish
# ID: 7014_6288_000586
# Leu ../data/mls/mls_polish/train/audio/7014/6288/7014_6288_000586.flac com sucesso!
#
# 330
# Idioma: polish
# ID: 1636_1447_000019
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000019.flac com sucesso!
#
# 331
# Idioma: polish
# ID: 4228_1447_000024
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000024.flac com sucesso!
#
# 332
# Idioma: polish
# ID: 7014_6834_002320
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_002320.flac com sucesso!
#
# 333
# Idioma: polish
# ID: 1636_1447_000008
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000008.flac com sucesso!
#
# 334
# Idioma: polish
# ID: 4228_1447_000039
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000039.flac com sucesso!
#
# 335
# Idioma: polish
# ID: 7014_6834_002248
# Leu ../data/mls/mls_polish/train/audio/7014/6834/7014_6834_002248.flac com sucesso!
#
# 336
# Idioma: polish
# ID: 1636_1447_000013
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000013.flac com sucesso!
#
# 337
# Idioma: polish
# ID: 4228_1447_000042
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000042.flac com sucesso!
#
# 338
# Idioma: polish
# ID: 6892_8912_002356
# Leu ../data/mls/mls_polish/train/audio/6892/8912/6892_8912_002356.flac com sucesso!
#
# 339
# Idioma: polish
# ID: 6439_5541_000082
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000082.flac com sucesso!
#
# 340
# Idioma: polish
# ID: 1890_1447_000023
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000023.flac com sucesso!
#
# 341
# Idioma: polish
# ID: 6892_9500_001891
# Leu ../data/mls/mls_polish/train/audio/6892/9500/6892_9500_001891.flac com sucesso!
#
# 342
# Idioma: polish
# ID: 6439_5541_000236
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000236.flac com sucesso!
#
# 343
# Idioma: polish
# ID: 1890_1447_000014
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000014.flac com sucesso!
#
# 344
# Idioma: polish
# ID: 6892_10920_000714
# Leu ../data/mls/mls_polish/train/audio/6892/10920/6892_10920_000714.flac com sucesso!
#
# 345
# Idioma: polish
# ID: 6439_5541_000089
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000089.flac com sucesso!
#
# 346
# Idioma: polish
# ID: 1890_1447_000013
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000013.flac com sucesso!
#
# 347
# Idioma: polish
# ID: 6892_8764_001981
# Leu ../data/mls/mls_polish/train/audio/6892/8764/6892_8764_001981.flac com sucesso!
#
# 348
# Idioma: polish
# ID: 6439_5541_000047
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000047.flac com sucesso!
#
# 349
# Idioma: polish
# ID: 1890_1447_000000
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000000.flac com sucesso!
#
# 350
# Idioma: polish
# ID: 6892_5541_000198
# Leu ../data/mls/mls_polish/train/audio/6892/5541/6892_5541_000198.flac com sucesso!
#
# 351
# Idioma: polish
# ID: 6439_5541_000024
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000024.flac com sucesso!
#
# 352
# Idioma: polish
# ID: 1890_1447_000011
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000011.flac com sucesso!
#
# 353
# Idioma: polish
# ID: 6892_10462_000610
# Leu ../data/mls/mls_polish/train/audio/6892/10462/6892_10462_000610.flac com sucesso!
#
# 354
# Idioma: polish
# ID: 6439_5541_000000
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000000.flac com sucesso!
#
# 355
# Idioma: polish
# ID: 1890_1447_000035
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000035.flac com sucesso!
#
# 356
# Idioma: polish
# ID: 6892_10674_001753
# Leu ../data/mls/mls_polish/train/audio/6892/10674/6892_10674_001753.flac com sucesso!
#
# 357
# Idioma: polish
# ID: 6439_5541_000248
# Leu ../data/mls/mls_polish/train/audio/6439/5541/6439_5541_000248.flac com sucesso!
#
# 358
# Idioma: polish
# ID: 1890_1447_000010
# Leu ../data/mls/mls_polish/train/audio/1890/1447/1890_1447_000010.flac com sucesso!
#
# 359
# Idioma: polish
# ID: 1636_1447_000032
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000032.flac com sucesso!
#
# 360
# Idioma: polish
# ID: 3492_2857_000036
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000036.flac com sucesso!
#
# 361
# Idioma: polish
# ID: 4228_1447_000004
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000004.flac com sucesso!
#
# 362
# Idioma: polish
# ID: 1636_1447_000006
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000006.flac com sucesso!
#
# 363
# Idioma: polish
# ID: 3492_2857_000047
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000047.flac com sucesso!
#
# 364
# Idioma: polish
# ID: 4228_1447_000032
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000032.flac com sucesso!
#
# 365
# Idioma: polish
# ID: 1636_1447_000022
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000022.flac com sucesso!
#
# 366
# Idioma: polish
# ID: 3492_2857_000043
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000043.flac com sucesso!
#
# 367
# Idioma: polish
# ID: 4228_1447_000016
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000016.flac com sucesso!
#
# 368
# Idioma: polish
# ID: 1636_1447_000030
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000030.flac com sucesso!
#
# 369
# Idioma: polish
# ID: 3492_2857_000019
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000019.flac com sucesso!
#
# 370
# Idioma: polish
# ID: 4228_1447_000025
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000025.flac com sucesso!
#
# 371
# Idioma: polish
# ID: 1636_1447_000025
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000025.flac com sucesso!
#
# 372
# Idioma: polish
# ID: 3492_2857_000032
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000032.flac com sucesso!
#
# 373
# Idioma: polish
# ID: 4228_1447_000006
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000006.flac com sucesso!
#
# 374
# Idioma: polish
# ID: 1636_1447_000020
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000020.flac com sucesso!
#
# 375
# Idioma: polish
# ID: 3492_2857_000033
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000033.flac com sucesso!
#
# 376
# Idioma: polish
# ID: 4228_1447_000043
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000043.flac com sucesso!
#
# 377
# Idioma: polish
# ID: 1636_1447_000005
# Leu ../data/mls/mls_polish/train/audio/1636/1447/1636_1447_000005.flac com sucesso!
#
# 378
# Idioma: polish
# ID: 3492_2857_000003
# Leu ../data/mls/mls_polish/train/audio/3492/2857/3492_2857_000003.flac com sucesso!
#
# 379
# Idioma: polish
# ID: 4228_1447_000028
# Leu ../data/mls/mls_polish/train/audio/4228/1447/4228_1447_000028.flac com sucesso!
#
# 380
# Idioma: polish
# ID: 10900_6473_000781
# Leu ../data/mls/mls_polish/train/audio/10900/6473/10900_6473_000781.flac com sucesso!
#
# 381
# ...
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000061.flac com sucesso!
#
# 823
# Idioma: spanish
# ID: 10982_9310_000022
# Leu ../data/mls/mls_spanish/train/audio/10982/9310/10982_9310_000022.flac com sucesso!
#
# 824
# Idioma: spanish
# ID: 11228_10604_000008
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000008.flac com sucesso!
#
# 825
# Idioma: spanish
# ID: 2262_2162_000000
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000000.flac com sucesso!
#
# 826
# Idioma: spanish
# ID: 12921_12700_000007
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000007.flac com sucesso!
#
# 827
# Idioma: spanish
# ID: 11772_11957_000003
# Leu ../data/mls/mls_spanish/train/audio/11772/11957/11772_11957_000003.flac com sucesso!
#
# 828
# Idioma: spanish
# ID: 8304_7613_000179
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000179.flac com sucesso!
#
# 829
# Idioma: spanish
# ID: 12921_12700_000006
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000006.flac com sucesso!
#
# 830
# Idioma: spanish
# ID: 11772_11957_000010
# Leu ../data/mls/mls_spanish/train/audio/11772/11957/11772_11957_000010.flac com sucesso!
#
# 831
# Idioma: spanish
# ID: 8304_7613_000128
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000128.flac com sucesso!
#
# 832
# Idioma: spanish
# ID: 12921_12700_000013
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000013.flac com sucesso!
#
# 833
# Idioma: spanish
# ID: 11772_11957_000002
# Leu ../data/mls/mls_spanish/train/audio/11772/11957/11772_11957_000002.flac com sucesso!
#
# 834
# Idioma: spanish
# ID: 8304_7613_000131
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000131.flac com sucesso!
#
# 835
# Idioma: spanish
# ID: 12921_12700_000018
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000018.flac com sucesso!
#
# 836
# Idioma: spanish
# ID: 11772_11957_000007
# Leu ../data/mls/mls_spanish/train/audio/11772/11957/11772_11957_000007.flac com sucesso!
#
# 837
# Idioma: spanish
# ID: 8304_7613_000132
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000132.flac com sucesso!
#
# 838
# Idioma: spanish
# ID: 12921_12700_000010
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000010.flac com sucesso!
#
# 839
# Idioma: spanish
# ID: 11772_11957_000005
# Leu ../data/mls/mls_spanish/train/audio/11772/11957/11772_11957_000005.flac com sucesso!
#
# 840
# Idioma: spanish
# ID: 8304_7613_000055
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000055.flac com sucesso!
#
# 841
# Idioma: spanish
# ID: 12921_12700_000004
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000004.flac com sucesso!
#
# 842
# Idioma: spanish
# ID: 8304_7613_000043
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000043.flac com sucesso!
#
# 843
# Idioma: spanish
# ID: 12921_12700_000009
# Leu ../data/mls/mls_spanish/train/audio/12921/12700/12921_12700_000009.flac com sucesso!
#
# 844
# Idioma: spanish
# ID: 8304_7613_000113
# Leu ../data/mls/mls_spanish/train/audio/8304/7613/8304_7613_000113.flac com sucesso!
#
# 845
# Idioma: spanish
# ID: 6615_11957_000042
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000042.flac com sucesso!
#
# 846
# Idioma: spanish
# ID: 3553_2162_000008
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000008.flac com sucesso!
#
# 847
# Idioma: spanish
# ID: 2262_2162_000057
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000057.flac com sucesso!
#
# 848
# Idioma: spanish
# ID: 6615_11957_000071
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000071.flac com sucesso!
#
# 849
# Idioma: spanish
# ID: 3553_2162_000001
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000001.flac com sucesso!
#
# 850
# Idioma: spanish
# ID: 2262_2162_000023
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000023.flac com sucesso!
#
# 851
# Idioma: spanish
# ID: 6615_11957_000028
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000028.flac com sucesso!
#
# 852
# Idioma: spanish
# ID: 3553_2162_000016
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000016.flac com sucesso!
#
# 853
# Idioma: spanish
# ID: 2262_2162_000065
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000065.flac com sucesso!
#
# 854
# Idioma: spanish
# ID: 6615_11957_000029
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000029.flac com sucesso!
#
# 855
# Idioma: spanish
# ID: 3553_2162_000018
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000018.flac com sucesso!
#
# 856
# Idioma: spanish
# ID: 2262_2162_000011
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000011.flac com sucesso!
#
# 857
# Idioma: spanish
# ID: 6615_11957_000016
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000016.flac com sucesso!
#
# 858
# Idioma: spanish
# ID: 3553_2162_000004
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000004.flac com sucesso!
#
# 859
# Idioma: spanish
# ID: 2262_2162_000021
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000021.flac com sucesso!
#
# 860
# Idioma: spanish
# ID: 6615_11957_000023
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000023.flac com sucesso!
#
# 861
# Idioma: spanish
# ID: 3553_2162_000010
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000010.flac com sucesso!
#
# 862
# Idioma: spanish
# ID: 2262_2162_000029
# Leu ../data/mls/mls_spanish/train/audio/2262/2162/2262_2162_000029.flac com sucesso!
#
# 863
# Idioma: spanish
# ID: 6615_11957_000077
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000077.flac com sucesso!
#
# 864
# Idioma: spanish
# ID: 3553_2162_000011
# Leu ../data/mls/mls_spanish/train/audio/3553/2162/3553_2162_000011.flac com sucesso!
#
# 865
# Idioma: spanish
# ID: 8886_9951_000019
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000019.flac com sucesso!
#
# 866
# Idioma: spanish
# ID: 10206_9503_000802
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000802.flac com sucesso!
#
# 867
# Idioma: spanish
# ID: 5047_4006_000003
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000003.flac com sucesso!
#
# 868
# Idioma: spanish
# ID: 8886_9951_000007
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000007.flac com sucesso!
#
# 869
# Idioma: spanish
# ID: 10206_9310_000131
# Leu ../data/mls/mls_spanish/train/audio/10206/9310/10206_9310_000131.flac com sucesso!
#
# 870
# Idioma: spanish
# ID: 5047_4006_000020
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000020.flac com sucesso!
#
# 871
# Idioma: spanish
# ID: 8886_9951_000006
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000006.flac com sucesso!
#
# 872
# Idioma: spanish
# ID: 10206_9503_000833
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000833.flac com sucesso!
#
# 873
# Idioma: spanish
# ID: 5047_4006_000008
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000008.flac com sucesso!
#
# 874
# Idioma: spanish
# ID: 8886_9951_000017
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000017.flac com sucesso!
#
# 875
# Idioma: spanish
# ID: 10206_9503_000711
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000711.flac com sucesso!
#
# 876
# Idioma: spanish
# ID: 5047_4006_000029
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000029.flac com sucesso!
#
# 877
# Idioma: spanish
# ID: 8886_9951_000015
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000015.flac com sucesso!
#
# 878
# Idioma: spanish
# ID: 10206_9503_000485
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000485.flac com sucesso!
#
# 879
# Idioma: spanish
# ID: 5047_4006_000032
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000032.flac com sucesso!
#
# 880
# Idioma: spanish
# ID: 8886_9951_000013
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000013.flac com sucesso!
#
# 881
# Idioma: spanish
# ID: 10206_9503_000469
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000469.flac com sucesso!
#
# 882
# Idioma: spanish
# ID: 5047_4006_000007
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000007.flac com sucesso!
#
# 883
# Idioma: spanish
# ID: 8886_9951_000009
# Leu ../data/mls/mls_spanish/train/audio/8886/9951/8886_9951_000009.flac com sucesso!
#
# 884
# Idioma: spanish
# ID: 10206_9503_000637
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000637.flac com sucesso!
#
# 885
# Idioma: spanish
# ID: 5047_4006_000045
# Leu ../data/mls/mls_spanish/train/audio/5047/4006/5047_4006_000045.flac com sucesso!
#
# 886
# Idioma: spanish
# ID: 8881_8550_000845
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000845.flac com sucesso!
#
# 887
# Idioma: spanish
# ID: 11228_10604_000009
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000009.flac com sucesso!
#
# 888
# Idioma: spanish
# ID: 6615_11957_000034
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000034.flac com sucesso!
#
# 889
# Idioma: spanish
# ID: 8881_8550_001452
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_001452.flac com sucesso!
#
# 890
# Idioma: spanish
# ID: 11228_10604_000004
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000004.flac com sucesso!
#
# 891
# Idioma: spanish
# ID: 6615_11957_000058
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000058.flac com sucesso!
#
# 892
# Idioma: spanish
# ID: 8881_8550_000594
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000594.flac com sucesso!
#
# 893
# Idioma: spanish
# ID: 11228_10604_000007
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000007.flac com sucesso!
#
# 894
# Idioma: spanish
# ID: 6615_11957_000078
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000078.flac com sucesso!
#
# 895
# Idioma: spanish
# ID: 8881_8550_000167
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000167.flac com sucesso!
#
# 896
# Idioma: spanish
# ID: 11228_10604_000013
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000013.flac com sucesso!
#
# 897
# Idioma: spanish
# ID: 6615_11957_000068
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000068.flac com sucesso!
#
# 898
# Idioma: spanish
# ID: 8881_8550_000095
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000095.flac com sucesso!
#
# 899
# Idioma: spanish
# ID: 11228_10604_000000
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000000.flac com sucesso!
#
# 900
# Idioma: spanish
# ID: 6615_11957_000000
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000000.flac com sucesso!
#
# 901
# Idioma: spanish
# ID: 8881_8550_000527
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000527.flac com sucesso!
#
# 902
# Idioma: spanish
# ID: 11228_10604_000001
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000001.flac com sucesso!
#
# 903
# Idioma: spanish
# ID: 6615_11957_000061
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000061.flac com sucesso!
#
# 904
# Idioma: spanish
# ID: 8881_8550_000747
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000747.flac com sucesso!
#
# 905
# Idioma: spanish
# ID: 11228_10604_000010
# Leu ../data/mls/mls_spanish/train/audio/11228/10604/11228_10604_000010.flac com sucesso!
#
# 906
# Idioma: spanish
# ID: 6615_11957_000007
# Leu ../data/mls/mls_spanish/train/audio/6615/11957/6615_11957_000007.flac com sucesso!
#
# 907
# Idioma: spanish
# ID: 10206_6706_000035
# Leu ../data/mls/mls_spanish/train/audio/10206/6706/10206_6706_000035.flac com sucesso!
#
# 908
# Idioma: spanish
# ID: 407_567_000025
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000025.flac com sucesso!
#
# 909
# Idioma: spanish
# ID: 11553_11957_000013
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000013.flac com sucesso!
#
# 910
# Idioma: spanish
# ID: 10206_9503_000062
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000062.flac com sucesso!
#
# 911
# Idioma: spanish
# ID: 407_567_000491
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000491.flac com sucesso!
#
# 912
# Idioma: spanish
# ID: 11553_11957_000022
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000022.flac com sucesso!
#
# 913
# Idioma: spanish
# ID: 10206_9503_000565
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000565.flac com sucesso!
#
# 914
# Idioma: spanish
# ID: 407_567_000982
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000982.flac com sucesso!
#
# 915
# Idioma: spanish
# ID: 11553_11957_000010
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000010.flac com sucesso!
#
# 916
# Idioma: spanish
# ID: 10206_9503_000290
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000290.flac com sucesso!
#
# 917
# Idioma: spanish
# ID: 407_567_000675
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000675.flac com sucesso!
#
# 918
# Idioma: spanish
# ID: 11553_11957_000006
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000006.flac com sucesso!
#
# 919
# Idioma: spanish
# ID: 10206_9503_000397
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000397.flac com sucesso!
#
# 920
# Idioma: spanish
# ID: 407_567_000473
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000473.flac com sucesso!
#
# 921
# Idioma: spanish
# ID: 11553_11957_000014
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000014.flac com sucesso!
#
# 922
# Idioma: spanish
# ID: 10206_9503_000456
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000456.flac com sucesso!
#
# 923
# Idioma: spanish
# ID: 407_567_000055
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000055.flac com sucesso!
#
# 924
# Idioma: spanish
# ID: 11553_11957_000020
# Leu ../data/mls/mls_spanish/train/audio/11553/11957/11553_11957_000020.flac com sucesso!
#
# 925
# Idioma: spanish
# ID: 10206_9503_000381
# Leu ../data/mls/mls_spanish/train/audio/10206/9503/10206_9503_000381.flac com sucesso!
#
# 926
# Idioma: spanish
# ID: 407_567_000303
# Leu ../data/mls/mls_spanish/train/audio/407/567/407_567_000303.flac com sucesso!
#
# 927
# Idioma: spanish
# ID: 6156_4006_000018
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000018.flac com sucesso!
#
# 928
# Idioma: spanish
# ID: 101_567_000201
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000201.flac com sucesso!
#
# 929
# Idioma: spanish
# ID: 8881_8550_001330
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_001330.flac com sucesso!
#
# 930
# Idioma: spanish
# ID: 6156_4006_000041
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000041.flac com sucesso!
#
# 931
# Idioma: spanish
# ID: 101_567_000200
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000200.flac com sucesso!
#
# 932
# Idioma: spanish
# ID: 8881_8550_001212
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_001212.flac com sucesso!
#
# 933
# Idioma: spanish
# ID: 6156_4006_000033
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000033.flac com sucesso!
#
# 934
# Idioma: spanish
# ID: 101_567_000251
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000251.flac com sucesso!
#
# 935
# Idioma: spanish
# ID: 8881_8550_001344
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_001344.flac com sucesso!
#
# 936
# Idioma: spanish
# ID: 6156_4006_000023
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000023.flac com sucesso!
#
# 937
# Idioma: spanish
# ID: 101_567_000035
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000035.flac com sucesso!
#
# 938
# Idioma: spanish
# ID: 8881_8550_000294
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000294.flac com sucesso!
#
# 939
# Idioma: spanish
# ID: 6156_4006_000005
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000005.flac com sucesso!
#
# 940
# Idioma: spanish
# ID: 101_567_000259
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000259.flac com sucesso!
#
# 941
# Idioma: spanish
# ID: 8881_8550_000620
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000620.flac com sucesso!
#
# 942
# Idioma: spanish
# ID: 6156_4006_000020
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000020.flac com sucesso!
#
# 943
# Idioma: spanish
# ID: 101_567_000034
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000034.flac com sucesso!
#
# 944
# Idioma: spanish
# ID: 8881_8550_000536
# Leu ../data/mls/mls_spanish/train/audio/8881/8550/8881_8550_000536.flac com sucesso!
#
# 945
# Idioma: spanish
# ID: 6156_4006_000028
# Leu ../data/mls/mls_spanish/train/audio/6156/4006/6156_4006_000028.flac com sucesso!
#
# 946
# Idioma: spanish
# ID: 101_567_000295
# Leu ../data/mls/mls_spanish/train/audio/101/567/101_567_000295.flac com sucesso!

# %%
df_audios["audio"] = audios
df_audios["length"] = lengths
df_audios["sr"] = srs

# %%
df_audios
# Out:
#     language                id speaker  book segment gender  \
# 0    italian  8828_8610_000510    8828  8610  000510      F
# 1    italian    659_547_000790     659   547  000790      F
# 2    italian    643_529_000116     643   529  000116      F
# 3    italian  8828_8610_000321    8828  8610  000321      F
# 4    italian    659_547_000279     659   547  000279      F
# ..       ...               ...     ...   ...     ...    ...
# 942  spanish  6156_4006_000020    6156  4006  000020      M
# 943  spanish    101_567_000034     101   567  000034      M
# 944  spanish  8881_8550_000536    8881  8550  000536      M
# 945  spanish  6156_4006_000028    6156  4006  000028      M
# 946  spanish    101_567_000295     101   567  000295      M
#
#                                         title  \
# 0    Novelle per un Anno, vol. 12: Il Viaggio
# 1                      Avventure di Pinocchio
# 2                             Divina Commedia
# 3    Novelle per un Anno, vol. 12: Il Viaggio
# 4                      Avventure di Pinocchio
# ..                                        ...
# 942                 Condenada y Otros Cuentos
# 943                             Don Quijote 1
# 944                   Aprendiz de Conspirador
# 945                 Condenada y Otros Cuentos
# 946                             Don Quijote 1
#
#                                                  audio  length     sr
# 0    [0.0, 3.0517578e-05, 3.0517578e-05, 6.1035156e...  318560  16000
# 1    [0.0, 3.0517578e-05, 0.0, 3.0517578e-05, 3.051...  186880  16000
# 2    [-0.007232666, -0.00491333, -0.0054016113, -0....  314560  16000
# 3    [0.0, 3.0517578e-05, 0.0, 0.0, 3.0517578e-05, ...  229920  16000
# 4    [0.0, 0.0, 0.0, -3.0517578e-05, -9.1552734e-05...  197440  16000
# ..                                                 ...     ...    ...
# 942  [0.0, 6.1035156e-05, 9.1552734e-05, 6.1035156e...  250880  16000
# 943  [0.0020751953, 0.0024108887, 0.002166748, 0.00...  297600  16000
# 944  [0.00076293945, 0.00064086914, 0.0002746582, 0...  162080  16000
# 945  [-0.00036621094, -0.0004272461, -0.00045776367...  238240  16000
# 946  [-0.0010375977, -0.0016174316, -0.0013427734, ...  178400  16000
#
# [947 rows x 10 columns]

# %%
gc.collect()
# Out:
# 4

# %% [markdown]
# Quanto tempo de áudio temos para cada idioma?

# %%
df_audios["duration_s"] = df_audios.apply(lambda x : librosa.get_duration(y=x["audio"], sr=x["sr"]), axis=1)

# %%
df_audios.head()
# Out:
#   language                id speaker  book segment gender  \
# 0  italian  8828_8610_000510    8828  8610  000510      F
# 1  italian    659_547_000790     659   547  000790      F
# 2  italian    643_529_000116     643   529  000116      F
# 3  italian  8828_8610_000321    8828  8610  000321      F
# 4  italian    659_547_000279     659   547  000279      F
#
#                                       title  \
# 0  Novelle per un Anno, vol. 12: Il Viaggio
# 1                    Avventure di Pinocchio
# 2                           Divina Commedia
# 3  Novelle per un Anno, vol. 12: Il Viaggio
# 4                    Avventure di Pinocchio
#
#                                                audio  length     sr  \
# 0  [0.0, 3.0517578e-05, 3.0517578e-05, 6.1035156e...  318560  16000
# 1  [0.0, 3.0517578e-05, 0.0, 3.0517578e-05, 3.051...  186880  16000
# 2  [-0.007232666, -0.00491333, -0.0054016113, -0....  314560  16000
# 3  [0.0, 3.0517578e-05, 0.0, 0.0, 3.0517578e-05, ...  229920  16000
# 4  [0.0, 0.0, 0.0, -3.0517578e-05, -9.1552734e-05...  197440  16000
#
#    duration_s
# 0       19.91
# 1       11.68
# 2       19.66
# 3       14.37
# 4       12.34

# %%
seconds_total = df_audios.groupby("language")["duration_s"].sum()
seconds_total
# Out:
# language
# italian       3559.770125
# polish        3575.904312
# portuguese    3581.950375
# spanish       3580.304125
# Name: duration_s, dtype: float64

# %%
minutes = seconds_total / 60
seconds = seconds_total - (minutes).astype(int) * 60

# %%
pd.concat([minutes.astype(int).rename("minutes").to_frame(), seconds.astype(int).rename("seconds").to_frame()], axis=1)
# Out:
#             minutes  seconds
# language
# italian          59       19
# polish           59       35
# portuguese       59       41
# spanish          59       40

# %% [markdown]
# Salvo o dataframe final

# %%
df_audios.to_csv("../data/audios.csv")
