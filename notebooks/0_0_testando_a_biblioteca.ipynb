# %% [markdown]
# Áudios com fs=16KHz

# %%
import pandas as pd
import numpy as np
import glob

import librosa
import librosa.display
import IPython.display as ipd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x, sr = librosa.load("../data/mls/mls_italian/train/audio/10121/9630/10121_9630_000001.flac", sr = 16000, mono = False)

# %%
x
# Out:
# array([9.1552734e-05, 3.0517578e-05, 0.0000000e+00, ..., 6.1035156e-05,
#        1.2207031e-04, 9.1552734e-05], dtype=float32)

# %%
x.shape
# Out:
# (178400,)

# %%
sr
# Out:
# 16000

# %%
librosa.display.waveshow(x, sr=sr)

# %%
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(x, rate=sr/2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(x, rate=sr*1.5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x, sr = librosa.load("../data/mls/mls_italian/train/audio/10121/9630/10121_9630_000001.flac", sr = 44100, mono = False)

# %%
x.shape
# Out:
# (491715,)

# %%
sr
# Out:
# 44100

# %%
librosa.display.waveshow(x, sr=sr)

# %%
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
